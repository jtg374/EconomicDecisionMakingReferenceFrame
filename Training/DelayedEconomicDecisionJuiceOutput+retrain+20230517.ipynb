# %%
from matplotlib import pyplot as plt 
# %matplotlib inline
# ---------------------- Import the package ---------------------------
from delayed_economic_deicision import DelayedEconomicDecision_AlternateOutput 
from psychrnn.backend.models.basic import Basic
import numpy as np

# %%
# ---------------------- Set up a basic model ---------------------------
dd = DelayedEconomicDecision_AlternateOutput(dt = 10, tau = 100, T = 4000, N_batch = 64,target_delay_duration=500,wait_duration=500,outputMode='juice')
network_params = dd.get_task_params() # get the params passed in and defined in pd 
network_params['name'] = 'model' # name the model uniquely if running mult models inunison
network_params['N_rec'] = 50 # set the number of recurrent units in the model
network_params['rec_noise'] = 0.1 # Noise into each recurrent unit. Default: 0.0
model.destruct()
model = Basic(network_params) # instantiate a basic vanilla RNN

# %%
# ---------------------- Train a basic model --------------------------- 
train_params = {}
train_params['training_iters']=300000
losses, initialTime, trainTime = model.train(dd,train_params) # train model to perform pd task
# ---------------------- Test the trained model --------------------------- 
x,target_output,mask, trial_params = dd.get_trial_batch() # get pd task inputs and outputs
model_output, model_state = model.test(x) # run the model on input x
# Out:
# Iter 640, Minibatch Loss= 0.094958
# Iter 1280, Minibatch Loss= 0.053468
# Iter 1920, Minibatch Loss= 0.048307
# Iter 2560, Minibatch Loss= 0.045191
# Iter 3200, Minibatch Loss= 0.045294
# Iter 3840, Minibatch Loss= 0.045094
# Iter 4480, Minibatch Loss= 0.043184
# Iter 5120, Minibatch Loss= 0.043787
# Iter 5760, Minibatch Loss= 0.044046
# Iter 6400, Minibatch Loss= 0.042244
# Iter 7040, Minibatch Loss= 0.042748
# Iter 7680, Minibatch Loss= 0.042377
# Iter 8320, Minibatch Loss= 0.043121
# Iter 8960, Minibatch Loss= 0.040292
# Iter 9600, Minibatch Loss= 0.038096
# Iter 10240, Minibatch Loss= 0.038603
# Iter 10880, Minibatch Loss= 0.035360
# Iter 11520, Minibatch Loss= 0.030872
# Iter 12160, Minibatch Loss= 0.034631
# Iter 12800, Minibatch Loss= 0.030814
# Iter 13440, Minibatch Loss= 0.029241
# Iter 14080, Minibatch Loss= 0.034804
# Iter 14720, Minibatch Loss= 0.026567
# Iter 15360, Minibatch Loss= 0.024329
# Iter 16000, Minibatch Loss= 0.022517
# Iter 16640, Minibatch Loss= 0.023750
# Iter 17280, Minibatch Loss= 0.021209
# Iter 17920, Minibatch Loss= 0.015786
# Iter 18560, Minibatch Loss= 0.021962
# Iter 19200, Minibatch Loss= 0.017531
# Iter 19840, Minibatch Loss= 0.017663
# Iter 20480, Minibatch Loss= 0.017871
# Iter 21120, Minibatch Loss= 0.016396
# Iter 21760, Minibatch Loss= 0.011337
# Iter 22400, Minibatch Loss= 0.021345
# Iter 23040, Minibatch Loss= 0.013681
# Iter 23680, Minibatch Loss= 0.013634
# Iter 24320, Minibatch Loss= 0.009604
# Iter 24960, Minibatch Loss= 0.019653
# Iter 25600, Minibatch Loss= 0.010803
# Iter 26240, Minibatch Loss= 0.007531
# Iter 26880, Minibatch Loss= 0.013440
# Iter 27520, Minibatch Loss= 0.012451
# Iter 28160, Minibatch Loss= 0.007507
# Iter 28800, Minibatch Loss= 0.024399
# Iter 29440, Minibatch Loss= 0.012835
# Iter 30080, Minibatch Loss= 0.006026
# Iter 30720, Minibatch Loss= 0.007655
# Iter 31360, Minibatch Loss= 0.012229
# Iter 32000, Minibatch Loss= 0.009064
# Iter 32640, Minibatch Loss= 0.016991
# Iter 33280, Minibatch Loss= 0.007559
# Iter 33920, Minibatch Loss= 0.010975
# Iter 34560, Minibatch Loss= 0.008324
# Iter 35200, Minibatch Loss= 0.009190
# Iter 35840, Minibatch Loss= 0.012270
# Iter 36480, Minibatch Loss= 0.009865
# Iter 37120, Minibatch Loss= 0.011738
# Iter 37760, Minibatch Loss= 0.009240
# Iter 38400, Minibatch Loss= 0.009827
# Iter 39040, Minibatch Loss= 0.010537
# Iter 39680, Minibatch Loss= 0.012032
# Iter 40320, Minibatch Loss= 0.011336
# Iter 40960, Minibatch Loss= 0.009942
# Iter 41600, Minibatch Loss= 0.008988
# Iter 42240, Minibatch Loss= 0.014489
# Iter 42880, Minibatch Loss= 0.010671
# Iter 43520, Minibatch Loss= 0.011722
# Iter 44160, Minibatch Loss= 0.008170
# Iter 44800, Minibatch Loss= 0.013522
# Iter 45440, Minibatch Loss= 0.005076
# Iter 46080, Minibatch Loss= 0.008675
# Iter 46720, Minibatch Loss= 0.005259
# Iter 47360, Minibatch Loss= 0.006561
# Iter 48000, Minibatch Loss= 0.011958
# Iter 48640, Minibatch Loss= 0.012514
# Iter 49280, Minibatch Loss= 0.011173
# Iter 49920, Minibatch Loss= 0.007900
# Iter 50560, Minibatch Loss= 0.007404
# Iter 51200, Minibatch Loss= 0.005096
# Iter 51840, Minibatch Loss= 0.007187
# Iter 52480, Minibatch Loss= 0.009768
# Iter 53120, Minibatch Loss= 0.016722
# Iter 53760, Minibatch Loss= 0.008844
# Iter 54400, Minibatch Loss= 0.013491
# Iter 55040, Minibatch Loss= 0.010794
# Iter 55680, Minibatch Loss= 0.005041
# Iter 56320, Minibatch Loss= 0.007139
# Iter 56960, Minibatch Loss= 0.008821
# Iter 57600, Minibatch Loss= 0.009285
# Iter 58240, Minibatch Loss= 0.010525
# Iter 58880, Minibatch Loss= 0.004049
# Iter 59520, Minibatch Loss= 0.006303
# Iter 60160, Minibatch Loss= 0.003505
# Iter 60800, Minibatch Loss= 0.006439
# Iter 61440, Minibatch Loss= 0.007332
# Iter 62080, Minibatch Loss= 0.010817
# Iter 62720, Minibatch Loss= 0.006387
# Iter 63360, Minibatch Loss= 0.008583
# Iter 64000, Minibatch Loss= 0.011123
# Iter 64640, Minibatch Loss= 0.008807
# Iter 65280, Minibatch Loss= 0.008509
# Iter 65920, Minibatch Loss= 0.009450
# Iter 66560, Minibatch Loss= 0.009926
# Iter 67200, Minibatch Loss= 0.013564
# Iter 67840, Minibatch Loss= 0.009350
# Iter 68480, Minibatch Loss= 0.008089
# Iter 69120, Minibatch Loss= 0.007602
# Iter 69760, Minibatch Loss= 0.009348
# Iter 70400, Minibatch Loss= 0.013565
# Iter 71040, Minibatch Loss= 0.013394
# Iter 71680, Minibatch Loss= 0.008223
# Iter 72320, Minibatch Loss= 0.007387
# Iter 72960, Minibatch Loss= 0.007900
# Iter 73600, Minibatch Loss= 0.007771
# Iter 74240, Minibatch Loss= 0.013734
# Iter 74880, Minibatch Loss= 0.007249
# Iter 75520, Minibatch Loss= 0.008230
# Iter 76160, Minibatch Loss= 0.008400
# Iter 76800, Minibatch Loss= 0.008949
# Iter 77440, Minibatch Loss= 0.008112
# Iter 78080, Minibatch Loss= 0.006956
# Iter 78720, Minibatch Loss= 0.006535
# Iter 79360, Minibatch Loss= 0.007789
# Iter 80000, Minibatch Loss= 0.005147
# Iter 80640, Minibatch Loss= 0.007722
# Iter 81280, Minibatch Loss= 0.005486
# Iter 81920, Minibatch Loss= 0.006284
# Iter 82560, Minibatch Loss= 0.012033
# Iter 83200, Minibatch Loss= 0.009333
# Iter 83840, Minibatch Loss= 0.007079
# Iter 84480, Minibatch Loss= 0.013934
# Iter 85120, Minibatch Loss= 0.006291
# Iter 85760, Minibatch Loss= 0.011496
# Iter 86400, Minibatch Loss= 0.016074
# Iter 87040, Minibatch Loss= 0.010538
# Iter 87680, Minibatch Loss= 0.004203
# Iter 88320, Minibatch Loss= 0.004596
# Iter 88960, Minibatch Loss= 0.012690
# Iter 89600, Minibatch Loss= 0.006513
# Iter 90240, Minibatch Loss= 0.005354
# Iter 90880, Minibatch Loss= 0.005231
# Iter 91520, Minibatch Loss= 0.007463
# Iter 92160, Minibatch Loss= 0.010611
# Iter 92800, Minibatch Loss= 0.003911
# Iter 93440, Minibatch Loss= 0.006548
# Iter 94080, Minibatch Loss= 0.005365
# Iter 94720, Minibatch Loss= 0.009913
# Iter 95360, Minibatch Loss= 0.005525
# Iter 96000, Minibatch Loss= 0.009510
# Iter 96640, Minibatch Loss= 0.004644
# Iter 97280, Minibatch Loss= 0.007067
# Iter 97920, Minibatch Loss= 0.002526
# Iter 98560, Minibatch Loss= 0.003650
# Iter 99200, Minibatch Loss= 0.004557
# Iter 99840, Minibatch Loss= 0.008365
# Iter 100480, Minibatch Loss= 0.005295
# Iter 101120, Minibatch Loss= 0.008299
# Iter 101760, Minibatch Loss= 0.012168
# Iter 102400, Minibatch Loss= 0.004263
# Iter 103040, Minibatch Loss= 0.008865
# Iter 103680, Minibatch Loss= 0.003033
# Iter 104320, Minibatch Loss= 0.006012
# Iter 104960, Minibatch Loss= 0.009452
# Iter 105600, Minibatch Loss= 0.003758
# Iter 106240, Minibatch Loss= 0.008672
# Iter 106880, Minibatch Loss= 0.004994
# Iter 107520, Minibatch Loss= 0.008194
# Iter 108160, Minibatch Loss= 0.009680
# Iter 108800, Minibatch Loss= 0.004223
# Iter 109440, Minibatch Loss= 0.002299
# Iter 110080, Minibatch Loss= 0.004411
# Iter 110720, Minibatch Loss= 0.002085
# Iter 111360, Minibatch Loss= 0.008861
# Iter 112000, Minibatch Loss= 0.009912
# Iter 112640, Minibatch Loss= 0.017520
# Iter 113280, Minibatch Loss= 0.007108
# Iter 113920, Minibatch Loss= 0.006802
# Iter 114560, Minibatch Loss= 0.006379
# Iter 115200, Minibatch Loss= 0.007080
# Iter 115840, Minibatch Loss= 0.006933
# Iter 116480, Minibatch Loss= 0.002855
# Iter 117120, Minibatch Loss= 0.005859
# Iter 117760, Minibatch Loss= 0.007790
# Iter 118400, Minibatch Loss= 0.015021
# Iter 119040, Minibatch Loss= 0.009759
# Iter 119680, Minibatch Loss= 0.011625
# Iter 120320, Minibatch Loss= 0.007077
# Iter 120960, Minibatch Loss= 0.010353
# Iter 121600, Minibatch Loss= 0.008322
# Iter 122240, Minibatch Loss= 0.005029
# Iter 122880, Minibatch Loss= 0.005684
# Iter 123520, Minibatch Loss= 0.004136
# Iter 124160, Minibatch Loss= 0.008993
# Iter 124800, Minibatch Loss= 0.004409
# Iter 125440, Minibatch Loss= 0.007459
# Iter 126080, Minibatch Loss= 0.007167
# Iter 126720, Minibatch Loss= 0.004091
# Iter 127360, Minibatch Loss= 0.005638
# Iter 128000, Minibatch Loss= 0.006999
# Iter 128640, Minibatch Loss= 0.004297
# Iter 129280, Minibatch Loss= 0.004263
# Iter 129920, Minibatch Loss= 0.004569
# Iter 130560, Minibatch Loss= 0.007139
# Iter 131200, Minibatch Loss= 0.004667
# Iter 131840, Minibatch Loss= 0.008109
# Iter 132480, Minibatch Loss= 0.004769
# Iter 133120, Minibatch Loss= 0.013427
# Iter 133760, Minibatch Loss= 0.009075
# Iter 134400, Minibatch Loss= 0.010010
# Iter 135040, Minibatch Loss= 0.003517
# Iter 135680, Minibatch Loss= 0.002371
# Iter 136320, Minibatch Loss= 0.006614
# Iter 136960, Minibatch Loss= 0.011446
# Iter 137600, Minibatch Loss= 0.007072
# Iter 138240, Minibatch Loss= 0.006026
# Iter 138880, Minibatch Loss= 0.004484
# Iter 139520, Minibatch Loss= 0.005114
# Iter 140160, Minibatch Loss= 0.004078
# Iter 140800, Minibatch Loss= 0.007110
# Iter 141440, Minibatch Loss= 0.005931
# Iter 142080, Minibatch Loss= 0.011217
# Iter 142720, Minibatch Loss= 0.008807
# Iter 143360, Minibatch Loss= 0.002072
# Iter 144000, Minibatch Loss= 0.003835
# Iter 144640, Minibatch Loss= 0.002402
# Iter 145280, Minibatch Loss= 0.008604
# Iter 145920, Minibatch Loss= 0.002248
# Iter 146560, Minibatch Loss= 0.008653
# Iter 147200, Minibatch Loss= 0.003419
# Iter 147840, Minibatch Loss= 0.007444
# Iter 148480, Minibatch Loss= 0.005399
# Iter 149120, Minibatch Loss= 0.004898
# Iter 149760, Minibatch Loss= 0.006999
# Iter 150400, Minibatch Loss= 0.002350
# Iter 151040, Minibatch Loss= 0.007895
# Iter 151680, Minibatch Loss= 0.005331
# Iter 152320, Minibatch Loss= 0.001518
# Iter 152960, Minibatch Loss= 0.001315
# Iter 153600, Minibatch Loss= 0.005931
# Iter 154240, Minibatch Loss= 0.005898
# Iter 154880, Minibatch Loss= 0.004322
# Iter 155520, Minibatch Loss= 0.006058
# Iter 156160, Minibatch Loss= 0.009463
# Iter 156800, Minibatch Loss= 0.001803
# Iter 157440, Minibatch Loss= 0.008696
# Iter 158080, Minibatch Loss= 0.001847
# Iter 158720, Minibatch Loss= 0.010403
# Iter 159360, Minibatch Loss= 0.001569
# Iter 160000, Minibatch Loss= 0.007485
# Iter 160640, Minibatch Loss= 0.005985
# Iter 161280, Minibatch Loss= 0.005672
# Iter 161920, Minibatch Loss= 0.005211
# Iter 162560, Minibatch Loss= 0.006261
# Iter 163200, Minibatch Loss= 0.009522
# Iter 163840, Minibatch Loss= 0.004788
# Iter 164480, Minibatch Loss= 0.009875
# Iter 165120, Minibatch Loss= 0.004634
# Iter 165760, Minibatch Loss= 0.003344
# Iter 166400, Minibatch Loss= 0.007076
# Iter 167040, Minibatch Loss= 0.002462
# Iter 167680, Minibatch Loss= 0.002619
# Iter 168320, Minibatch Loss= 0.004069
# Iter 168960, Minibatch Loss= 0.007913
# Iter 169600, Minibatch Loss= 0.003993
# Iter 170240, Minibatch Loss= 0.007423
# Iter 170880, Minibatch Loss= 0.003076
# Iter 171520, Minibatch Loss= 0.008242
# Iter 172160, Minibatch Loss= 0.005484
# Iter 172800, Minibatch Loss= 0.006071
# Iter 173440, Minibatch Loss= 0.003797
# Iter 174080, Minibatch Loss= 0.007097
# Iter 174720, Minibatch Loss= 0.003091
# Iter 175360, Minibatch Loss= 0.008163
# Iter 176000, Minibatch Loss= 0.003702
# Iter 176640, Minibatch Loss= 0.004676
# Iter 177280, Minibatch Loss= 0.010903
# Iter 177920, Minibatch Loss= 0.007064
# Iter 178560, Minibatch Loss= 0.003048
# Iter 179200, Minibatch Loss= 0.002580
# Iter 179840, Minibatch Loss= 0.005348
# Iter 180480, Minibatch Loss= 0.004493
# Iter 181120, Minibatch Loss= 0.003339
# Iter 181760, Minibatch Loss= 0.006222
# Iter 182400, Minibatch Loss= 0.008851
# Iter 183040, Minibatch Loss= 0.006708
# Iter 183680, Minibatch Loss= 0.004140
# Iter 184320, Minibatch Loss= 0.003947
# Iter 184960, Minibatch Loss= 0.004600
# Iter 185600, Minibatch Loss= 0.004482
# Iter 186240, Minibatch Loss= 0.003045
# Iter 186880, Minibatch Loss= 0.004071
# Iter 187520, Minibatch Loss= 0.005486
# Iter 188160, Minibatch Loss= 0.006558
# Iter 188800, Minibatch Loss= 0.003500
# Iter 189440, Minibatch Loss= 0.010354
# Iter 190080, Minibatch Loss= 0.004946
# Iter 190720, Minibatch Loss= 0.006893
# Iter 191360, Minibatch Loss= 0.009324
# Iter 192000, Minibatch Loss= 0.006351
# Iter 192640, Minibatch Loss= 0.007068
# Iter 193280, Minibatch Loss= 0.009996
# Iter 193920, Minibatch Loss= 0.007268
# Iter 194560, Minibatch Loss= 0.003475
# Iter 195200, Minibatch Loss= 0.004497
# Iter 195840, Minibatch Loss= 0.003609
# Iter 196480, Minibatch Loss= 0.001845
# Iter 197120, Minibatch Loss= 0.011042
# Iter 197760, Minibatch Loss= 0.006849
# Iter 198400, Minibatch Loss= 0.005330
# Iter 199040, Minibatch Loss= 0.006183
# Iter 199680, Minibatch Loss= 0.006566
# Iter 200320, Minibatch Loss= 0.007356
# Iter 200960, Minibatch Loss= 0.008687
# Iter 201600, Minibatch Loss= 0.006006
# Iter 202240, Minibatch Loss= 0.010536
# Iter 202880, Minibatch Loss= 0.009163
# Iter 203520, Minibatch Loss= 0.001962
# Iter 204160, Minibatch Loss= 0.007073
# Iter 204800, Minibatch Loss= 0.011083
# Iter 205440, Minibatch Loss= 0.001498
# Iter 206080, Minibatch Loss= 0.010939
# Iter 206720, Minibatch Loss= 0.006643
# Iter 207360, Minibatch Loss= 0.006116
# Iter 208000, Minibatch Loss= 0.004102
# Iter 208640, Minibatch Loss= 0.004637
# Iter 209280, Minibatch Loss= 0.009946
# Iter 209920, Minibatch Loss= 0.003476
# Iter 210560, Minibatch Loss= 0.002519
# Iter 211200, Minibatch Loss= 0.005277
# Iter 211840, Minibatch Loss= 0.004278
# Iter 212480, Minibatch Loss= 0.004088
# Iter 213120, Minibatch Loss= 0.004200
# Iter 213760, Minibatch Loss= 0.013478
# Iter 214400, Minibatch Loss= 0.006160
# Iter 215040, Minibatch Loss= 0.005399
# Iter 215680, Minibatch Loss= 0.010733
# Iter 216320, Minibatch Loss= 0.001539
# Iter 216960, Minibatch Loss= 0.001540
# Iter 217600, Minibatch Loss= 0.005738
# Iter 218240, Minibatch Loss= 0.008874
# Iter 218880, Minibatch Loss= 0.003270
# Iter 219520, Minibatch Loss= 0.004641
# Iter 220160, Minibatch Loss= 0.014299
# Iter 220800, Minibatch Loss= 0.010505
# Iter 221440, Minibatch Loss= 0.010390
# Iter 222080, Minibatch Loss= 0.007884
# Iter 222720, Minibatch Loss= 0.013962
# Iter 223360, Minibatch Loss= 0.005389
# Iter 224000, Minibatch Loss= 0.008458
# Iter 224640, Minibatch Loss= 0.003143
# Iter 225280, Minibatch Loss= 0.007779
# Iter 225920, Minibatch Loss= 0.004320
# Iter 226560, Minibatch Loss= 0.003370
# Iter 227200, Minibatch Loss= 0.005159
# Iter 227840, Minibatch Loss= 0.009994
# Iter 228480, Minibatch Loss= 0.001902
# Iter 229120, Minibatch Loss= 0.005267
# Iter 229760, Minibatch Loss= 0.009881
# Iter 230400, Minibatch Loss= 0.002191
# Iter 231040, Minibatch Loss= 0.005339
# Iter 231680, Minibatch Loss= 0.009532
# Iter 232320, Minibatch Loss= 0.003063
# Iter 232960, Minibatch Loss= 0.002985
# Iter 233600, Minibatch Loss= 0.003394
# Iter 234240, Minibatch Loss= 0.001672
# Iter 234880, Minibatch Loss= 0.004431
# Iter 235520, Minibatch Loss= 0.005984
# Iter 236160, Minibatch Loss= 0.009917
# Iter 236800, Minibatch Loss= 0.005414
# Iter 237440, Minibatch Loss= 0.005884
# Iter 238080, Minibatch Loss= 0.010018
# Iter 238720, Minibatch Loss= 0.012545
# Iter 239360, Minibatch Loss= 0.008379
# Iter 240000, Minibatch Loss= 0.005814
# Iter 240640, Minibatch Loss= 0.002584
# Iter 241280, Minibatch Loss= 0.003546
# Iter 241920, Minibatch Loss= 0.008962
# Iter 242560, Minibatch Loss= 0.003930
# Iter 243200, Minibatch Loss= 0.005298
# Iter 243840, Minibatch Loss= 0.003773
# Iter 244480, Minibatch Loss= 0.001274
# Iter 245120, Minibatch Loss= 0.008259
# Iter 245760, Minibatch Loss= 0.006085
# Iter 246400, Minibatch Loss= 0.005259
# Iter 247040, Minibatch Loss= 0.007556
# Iter 247680, Minibatch Loss= 0.007483
# Iter 248320, Minibatch Loss= 0.005479
# Iter 248960, Minibatch Loss= 0.010375
# Iter 249600, Minibatch Loss= 0.001138
# Iter 250240, Minibatch Loss= 0.005913
# Iter 250880, Minibatch Loss= 0.002316
# Iter 251520, Minibatch Loss= 0.008720
# Iter 252160, Minibatch Loss= 0.001831
# Iter 252800, Minibatch Loss= 0.006458
# Iter 253440, Minibatch Loss= 0.003582
# Iter 254080, Minibatch Loss= 0.005974
# Iter 254720, Minibatch Loss= 0.003560
# Iter 255360, Minibatch Loss= 0.000917
# Iter 256000, Minibatch Loss= 0.007057
# Iter 256640, Minibatch Loss= 0.003165
# Iter 257280, Minibatch Loss= 0.001049
# Iter 257920, Minibatch Loss= 0.005909
# Iter 258560, Minibatch Loss= 0.004002
# Iter 259200, Minibatch Loss= 0.007369
# Iter 259840, Minibatch Loss= 0.005714
# Iter 260480, Minibatch Loss= 0.005549
# Iter 261120, Minibatch Loss= 0.007648
# Iter 261760, Minibatch Loss= 0.003482
# Iter 262400, Minibatch Loss= 0.006020
# Iter 263040, Minibatch Loss= 0.003401
# Iter 263680, Minibatch Loss= 0.004322
# Iter 264320, Minibatch Loss= 0.001498
# Iter 264960, Minibatch Loss= 0.003397
# Iter 265600, Minibatch Loss= 0.003905
# Iter 266240, Minibatch Loss= 0.005112
# Iter 266880, Minibatch Loss= 0.003617
# Iter 267520, Minibatch Loss= 0.002765
# Iter 268160, Minibatch Loss= 0.001706
# Iter 268800, Minibatch Loss= 0.001330
# Iter 269440, Minibatch Loss= 0.008755
# Iter 270080, Minibatch Loss= 0.003530
# Iter 270720, Minibatch Loss= 0.006149
# Iter 271360, Minibatch Loss= 0.017520
# Iter 272000, Minibatch Loss= 0.004063
# Iter 272640, Minibatch Loss= 0.003963
# Iter 273280, Minibatch Loss= 0.006786
# Iter 273920, Minibatch Loss= 0.006656
# Iter 274560, Minibatch Loss= 0.009477
# Iter 275200, Minibatch Loss= 0.003730
# Iter 275840, Minibatch Loss= 0.003349
# Iter 276480, Minibatch Loss= 0.003214
# Iter 277120, Minibatch Loss= 0.002311
# Iter 277760, Minibatch Loss= 0.003486
# Iter 278400, Minibatch Loss= 0.001014
# Iter 279040, Minibatch Loss= 0.004843
# Iter 279680, Minibatch Loss= 0.005598
# Iter 280320, Minibatch Loss= 0.007375
# Iter 280960, Minibatch Loss= 0.003461
# Iter 281600, Minibatch Loss= 0.001014
# Iter 282240, Minibatch Loss= 0.005258
# Iter 282880, Minibatch Loss= 0.017115
# Iter 283520, Minibatch Loss= 0.005365
# Iter 284160, Minibatch Loss= 0.001479
# Iter 284800, Minibatch Loss= 0.004024
# Iter 285440, Minibatch Loss= 0.011708
# Iter 286080, Minibatch Loss= 0.003328
# Iter 286720, Minibatch Loss= 0.003119
# Iter 287360, Minibatch Loss= 0.003797
# Iter 288000, Minibatch Loss= 0.003150
# Iter 288640, Minibatch Loss= 0.008008
# Iter 289280, Minibatch Loss= 0.004352
# Iter 289920, Minibatch Loss= 0.002947
# Iter 290560, Minibatch Loss= 0.006116
# Iter 291200, Minibatch Loss= 0.005570
# Iter 291840, Minibatch Loss= 0.002613
# Iter 292480, Minibatch Loss= 0.004797
# Iter 293120, Minibatch Loss= 0.007566
# Iter 293760, Minibatch Loss= 0.003899
# Iter 294400, Minibatch Loss= 0.006640
# Iter 295040, Minibatch Loss= 0.003234
# Iter 295680, Minibatch Loss= 0.005699
# Iter 296320, Minibatch Loss= 0.002982
# Iter 296960, Minibatch Loss= 0.003589
# Iter 297600, Minibatch Loss= 0.006489
# Iter 298240, Minibatch Loss= 0.005812
# Iter 298880, Minibatch Loss= 0.001434
# Iter 299520, Minibatch Loss= 0.001259
# Optimization finished!

# %%
plt.plot(losses)
plt.ylabel("Loss")
plt.xlabel("Training Iteration")
plt.title("Loss During Training")
# Out:
# Text(0.5, 1.0, 'Loss During Training')

# %%
# ---------------------- Plot the results ---------------------------
nn=20
plt.plot(x[nn,:,:]+0.02*np.random.normal(size=(9,)))
plt.legend(['stimA','stimB','targetLA','targetLB','targetRA','targetRB','target12','target21','fixation'])
# ---------------------- Teardown the model -------------------------
# model.destruct()

# %%
plt.plot(model_output[nn,:,:])
plt.plot(target_output[nn,:,:])
plt.legend(['out1','out2','target1','target2'])

# %%
import numpy as np
temp = np.mean(mask * model_output,1)
choiceLR = temp[:,1]>temp[:,0]
choiceLR = choiceLR*2-1 # pos right high, neg left high

choiceFrame = [trial_params[i]['choiceFrame'] for i in range(len(trial_params))]


locAB = [(1 if trial_params[i]['locAB']=='AB' or trial_params[i]['locAB']=='12' else -1) for i in range(len(trial_params))]
loc12 = locAB
seqAB = [(1 if trial_params[i]['seqAB']=='AB' else -1) for i in range(len(trial_params))]

choiceAB = np.array([(choiceLR[i] * locAB[i] if choiceFrame[i]=='juice' else choiceLR[i] * locAB[i] * seqAB[i]) for i in range(len(trial_params)) ])  # pos A neg B
choice12 = np.array([(choiceAB[i] * seqAB[i] if choiceFrame[i]=='juice' else choiceLR[i] * locAB[i]) for i in range(len(trial_params)) ])  # pos A neg B


qAs = np.array([trial_params[i]['qA'] for i in range(len(trial_params))])
qBs = np.array([trial_params[i]['qB'] for i in range(len(trial_params))])
offerRatio = qBs/qAs
offerRatio[offerRatio==np.Inf] = 5
ChoiceTarget =  np.array([trial_params[i]['chooseB'] for i in range(len(trial_params))])



oRs = np.unique(offerRatio)
cu = np.zeros(oRs.shape)
cc = np.zeros(oRs.shape)

for ii,oR in enumerate(oRs):
    cu[ii] = np.mean(choiceAB[offerRatio==oR])
    cc[ii] = np.mean(ChoiceTarget[offerRatio==oR])
plt.plot(oRs,cc,'o',label='target')
plt.plot(oRs,(cu+1)/2,'o',label='simulation')
plt.legend()
# Out:
# /Users/jtg374/anaconda3/envs/psychrnn/lib/python3.6/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in true_divide

# %%
dd.a1_choice
# Out:
# 13

# %%
weights = model.get_weights()
import datetime
now = datetime.datetime.now().strftime('%Y%m%d-%H-%m')
model.save('./DelayedEconomicDecision'+now)

# %%
seqAB = [(1 if trial_params[i]['seqAB']=='AB' else -1) for i in range(len(trial_params))]
choice12 = choiceAB*seqAB # pos first neg second
plt.plot(np.mean(model_state[choice12==1,:,:],0)-np.mean(model_state[choice12==-1,:,:],0))
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf758d8cf8>,
#  <matplotlib.lines.Line2D at 0x7fbf758d8d68>,
#  <matplotlib.lines.Line2D at 0x7fbf758d8e10>,
#  <matplotlib.lines.Line2D at 0x7fbf758d8eb8>,
#  <matplotlib.lines.Line2D at 0x7fbf758d8f60>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6048>,
#  <matplotlib.lines.Line2D at 0x7fbf758c60f0>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6198>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6240>,
#  <matplotlib.lines.Line2D at 0x7fbf758c62e8>,
#  <matplotlib.lines.Line2D at 0x7fbf758d8cc0>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6400>,
#  <matplotlib.lines.Line2D at 0x7fbf758c64a8>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6550>,
#  <matplotlib.lines.Line2D at 0x7fbf758c65f8>,
#  <matplotlib.lines.Line2D at 0x7fbf758c66a0>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6748>,
#  <matplotlib.lines.Line2D at 0x7fbf758c67f0>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6898>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6940>,
#  <matplotlib.lines.Line2D at 0x7fbf758c69e8>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6a90>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6b38>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6be0>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6c88>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6d30>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6dd8>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6e80>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6f28>,
#  <matplotlib.lines.Line2D at 0x7fbf758c6fd0>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2c88>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2c18>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2d68>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2860>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2518>,
#  <matplotlib.lines.Line2D at 0x7fbf758b27b8>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2fd0>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2ef0>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2f98>,
#  <matplotlib.lines.Line2D at 0x7fbf758b22b0>,
#  <matplotlib.lines.Line2D at 0x7fbf758b20b8>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2208>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2a90>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2b38>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2940>,
#  <matplotlib.lines.Line2D at 0x7fbf758b29e8>,
#  <matplotlib.lines.Line2D at 0x7fbf758b24e0>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2588>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2390>,
#  <matplotlib.lines.Line2D at 0x7fbf758b2438>]

# %%
plt.plot(np.mean(model_state[choiceLR==1,:,:],0)-np.mean(model_state[choiceLR==-1,:,:],0))
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf32a11358>,
#  <matplotlib.lines.Line2D at 0x7fbf32a114a8>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11da0>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11cc0>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11c50>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11ba8>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11668>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11748>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11588>,
#  <matplotlib.lines.Line2D at 0x7fbf32a115c0>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11208>,
#  <matplotlib.lines.Line2D at 0x7fbf32a111d0>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11278>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11048>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11a20>,
#  <matplotlib.lines.Line2D at 0x7fbf32a11400>,
#  <matplotlib.lines.Line2D at 0x7fbf32a114e0>,
#  <matplotlib.lines.Line2D at 0x7fbf3296cef0>,
#  <matplotlib.lines.Line2D at 0x7fbf3296cf60>,
#  <matplotlib.lines.Line2D at 0x7fbf3296ceb8>,
#  <matplotlib.lines.Line2D at 0x7fbf3296ccc0>,
#  <matplotlib.lines.Line2D at 0x7fbf3296cdd8>,
#  <matplotlib.lines.Line2D at 0x7fbf3296cda0>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c898>,
#  <matplotlib.lines.Line2D at 0x7fbf3296ca20>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c630>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c6d8>,
#  <matplotlib.lines.Line2D at 0x7fbf3296ccf8>,
#  <matplotlib.lines.Line2D at 0x7fbf3296cc18>,
#  <matplotlib.lines.Line2D at 0x7fbf3296cba8>,
#  <matplotlib.lines.Line2D at 0x7fbf3296cb00>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c438>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c4e0>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c470>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c390>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c2b0>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c198>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c160>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c208>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c908>,
#  <matplotlib.lines.Line2D at 0x7fbf3296c9e8>,
#  <matplotlib.lines.Line2D at 0x7fbf329690b8>,
#  <matplotlib.lines.Line2D at 0x7fbf32969160>,
#  <matplotlib.lines.Line2D at 0x7fbf32969208>,
#  <matplotlib.lines.Line2D at 0x7fbf329692b0>,
#  <matplotlib.lines.Line2D at 0x7fbf32969358>,
#  <matplotlib.lines.Line2D at 0x7fbf32969400>,
#  <matplotlib.lines.Line2D at 0x7fbf329694a8>,
#  <matplotlib.lines.Line2D at 0x7fbf32969550>,
#  <matplotlib.lines.Line2D at 0x7fbf329695f8>]

# %%
plt.plot(np.mean(model_state[choiceAB==1,:,:],0)-np.mean(model_state[choiceAB==-1,:,:],0))
# Out:
# [<matplotlib.lines.Line2D at 0x7fbf7577e128>,
#  <matplotlib.lines.Line2D at 0x7fbf7577e160>,
#  <matplotlib.lines.Line2D at 0x7fbf75776080>,
#  <matplotlib.lines.Line2D at 0x7fbf75776128>,
#  <matplotlib.lines.Line2D at 0x7fbf757761d0>,
#  <matplotlib.lines.Line2D at 0x7fbf75776278>,
#  <matplotlib.lines.Line2D at 0x7fbf75776320>,
#  <matplotlib.lines.Line2D at 0x7fbf757763c8>,
#  <matplotlib.lines.Line2D at 0x7fbf75776470>,
#  <matplotlib.lines.Line2D at 0x7fbf75776518>,
#  <matplotlib.lines.Line2D at 0x7fbf7577e9e8>,
#  <matplotlib.lines.Line2D at 0x7fbf75776630>,
#  <matplotlib.lines.Line2D at 0x7fbf757766d8>,
#  <matplotlib.lines.Line2D at 0x7fbf75776780>,
#  <matplotlib.lines.Line2D at 0x7fbf75776828>,
#  <matplotlib.lines.Line2D at 0x7fbf757768d0>,
#  <matplotlib.lines.Line2D at 0x7fbf75776978>,
#  <matplotlib.lines.Line2D at 0x7fbf75776a20>,
#  <matplotlib.lines.Line2D at 0x7fbf75776ac8>,
#  <matplotlib.lines.Line2D at 0x7fbf75776b70>,
#  <matplotlib.lines.Line2D at 0x7fbf75776c18>,
#  <matplotlib.lines.Line2D at 0x7fbf75776cc0>,
#  <matplotlib.lines.Line2D at 0x7fbf75776d68>,
#  <matplotlib.lines.Line2D at 0x7fbf75776e10>,
#  <matplotlib.lines.Line2D at 0x7fbf75776eb8>,
#  <matplotlib.lines.Line2D at 0x7fbf75776f60>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c048>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c0f0>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c198>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c240>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c2e8>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c390>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c438>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c4e0>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c588>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c630>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c6d8>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c780>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c828>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c8d0>,
#  <matplotlib.lines.Line2D at 0x7fbf7578c978>,
#  <matplotlib.lines.Line2D at 0x7fbf7578ca20>,
#  <matplotlib.lines.Line2D at 0x7fbf7578cac8>,
#  <matplotlib.lines.Line2D at 0x7fbf7578cb70>,
#  <matplotlib.lines.Line2D at 0x7fbf7578cc18>,
#  <matplotlib.lines.Line2D at 0x7fbf7578ccc0>,
#  <matplotlib.lines.Line2D at 0x7fbf7578cd68>,
#  <matplotlib.lines.Line2D at 0x7fbf7578ce10>,
#  <matplotlib.lines.Line2D at 0x7fbf7578ceb8>,
#  <matplotlib.lines.Line2D at 0x7fbf7578cf60>]

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import RepeatedStratifiedKFold, cross_val_score



nT = x.shape[1]
accuracyLR = np.zeros(nT)
accuracyAB = np.zeros(nT)
accuracy12 = np.zeros(nT)

for iT in range(nT):
    Xt = model_state[:,iT,:].squeeze()
    cv = RepeatedStratifiedKFold(n_splits=5,n_repeats=10)
    scoreLR = cross_val_score(LinearDiscriminantAnalysis(),Xt,choiceLR,scoring='accuracy',cv=cv)
    scoreAB = cross_val_score(LinearDiscriminantAnalysis(),Xt,choiceAB,scoring='accuracy',cv=cv)
    score12 = cross_val_score(LinearDiscriminantAnalysis(),Xt,choice12,scoring='accuracy',cv=cv)
    accuracyLR[iT] = np.mean(scoreLR)
    accuracyAB[iT] = np.mean(scoreAB)
    accuracy12[iT] = np.mean(score12)

plt.plot(accuracyLR)
plt.plot(accuracyAB)
plt.plot(accuracy12)
plt.legend(['space','juice','order'])
plt.xlabel('time')
plt.ylabel('accuracy')
# Out:
# Text(0, 0.5, 'accuracy')
